# %%
import json
import gradio as gr
import numpy as np
import requests
import pandas as pd
import pymongo
import names
import random
import pickle

# %%
# Load model
filename = 'random_model_fixlengkap.pkl'
with open(filename, 'rb') as f:
    model = pickle.load(f)
# Out:
# C:\Users\TEMP\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.0.2 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\TEMP\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 1.0.2 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# Connect to mongoDB
# MONGODB_URI = "mongodb+srv://if5171:MLDSAI@datingappcluster.oe2g2ap.mongodb.net/?retryWrites=true&w=majority"

# client = pymongo.MongoClient(MONGODB_URI) 
# db = client['datingDB']
# print("Database loaded")
# details = db['details'].find_one()
# users = db['users'].find()

# strToNum = details['strToNum']
# numToStr = details['numToStr']

# %%
# Mapping attribute
details = {
    "numToStr": {
        "gender": {
            "1": "Male",
            "2": "Female"
        },
        "field": {
            "1": "Law",
            "2": "Math",
            "3": "Social Science, Psychologist",
            "4": "Medical Science, Pharmaceuticals, and Bio Tech",
            "5": "Engineering",
            "6": "English/Creative Writing/ Journalism",
            "7": "History/Religion/Philosophy",
            "8": "Business/Econ/Finance",
            "9": "Education, Academia",
            "10": "Biological Sciences/Chemistry/Physics",
            "11": "Social Work",
            "12": "Undergrad/undecided",
            "13": "Political Science/International Affairs",
            "14": "Film",
            "15": "Fine Arts/Arts Administration",
            "16": "Languages",
            "17": "Architecture",
            "18": "Other"
        },
        "race": {
            "1": "Black/African American",
            "2": "European/Caucasian-American",
            "3": "Latino/Hispanic American",
            "4": "Asian/Pacific Islander/Asian-American",
            "5": "Native American",
            "6": "Other"
        },
        "go_out": {
            "1": "Several times a week",
            "2": "Twice a week",
            "3": "Once a week",
            "4": "Twice a month",
            "5": "Once a month",
            "6": "Several times a year",
            "7": "Almost never"
        },

        "date": {
            "1": "Several times a week",
            "2": "Twice a week",
            "3": "Once a week",
            "4": "Twice a month",
            "5": "Once a month",
            "6": "Several times a year",
            "7": "Almost never"
        },

        "goal": {
            "1": "Seemed like a fun night out",
            "2": "To meet new people",
            "3": "To get a date",
            "4": "Looking for a serious relationship",
            "5": "To say I did it",
            "6": "Other"
        },
        "career": {
            "1": "Lawyer",
            "2": "Academic/Research",
            "3": "Psychologist ",
            "4": "Doctor/Medicine",
            "5": "Engineer",
            "6": "Creative Arts/Entertainment",
            "7": "Banking/Consulting/Finance/Marketing/Business/CEO/Entrepreneur/Admin",
            "8": "Real Estate",
            "9": "International/Humanitarian Affairs",
            "10": "Undecided",
            "11": "Social Work",
            "12": "Speech Pathology",
            "13": "Politics",
            "14": "Pro sports/Athletics",
            "15": "Other",
            "16": "Journalism",
            "17": "Architecture"
        }


    },
    "strToNum": {
        "gender": {
            "Male": "1",
            "Female": "2"
        },
        "field": {
            "Law": "1",
            "Math": "2",
            "Social Science, Psychologist": "3",
            "Medical Science, Pharmaceuticals, and Bio Tech": "4",
            "Engineering": "5",
            "English/Creative Writing/ Journalism": "6",
            "History/Religion/Philosophy": "7",
            "Business/Econ/Finance": "8",
            "Education, Academia": "9",
            "Biological Sciences/Chemistry/Physics": "10",
            "Social Work": "11",
            "Undergrad/undecided": "12",
            "Political Science/International Affairs": "13",
            "Film": "14",
            "Fine Arts/Arts Administration": "15",
            "Languages": "16",
            "Architecture": "17",
            "Other": "18"

        },

        "race": {
            "Black/African American": "1",
            "European/Caucasian-American": "2",
            "Latino/Hispanic American": "3",
            "Asian/Pacific Islander/Asian-American": "4",
            "Native American": "5",
            "Other": "6"
        },

        "go_out": {
            "Several times a week": "1",
            "Twice a week": "2",
            "Once a week": "3",
            "Twice a month": "4",
            "Once a month": "5",
            "Several times a year": "6",
            "Almost never": "7"
        },
        "date": {
            "Several times a week": "1",
            "Twice a week": "2",
            "Once a week": "3",
            "Twice a month": "4",
            "Once a month": "5",
            "Several times a year": "6",
            "Almost never": "7"
        },

        "goal": {
            "Seemed like a fun night out": "1",
            "To meet new people": "2",
            "To get a date": "3",
            "Looking for a serious relationship": "4",
            "To say I did it": "5",
            "Other": "6"
        },
        "career": {
            "Lawyer": "1",
            "Academic/Research": "2",
            "Psychologist ": "3",
            "Doctor/Medicine": "4",
            "Engineer": "5",
            "Creative Arts/Entertainment": "6",
            "Banking/Consulting/Finance/Marketing/Business/CEO/Entrepreneur/Admin": "7",
            "Real Estate": "8",
            "International/Humanitarian Affairs": "9",
            "Undecided": "10",
            "Social Work": "11",
            "Speech Pathology": "12",
            "Politics": "13",
            "Pro sports/Athletics": "14",
            "Other": "15",
            "Journalism": "16",
            "Architecture": "17"
        }

    }
}

# %%
# Randomize users profile
users = []
for i in range(40):
    user = dict()
    if i % 2 == 0:
        gender_str = "female"
        gender = 2
    else:
        gender_str = "male"
        gender = 1
    
    user['name'] = names.get_full_name(gender=gender_str)
    user['gender'] = gender
    user['age'] = random.randint(20, 36)
    user['race'] = random.randint(1, 6)
    user['field'] = random.randint(1, 18)
    user['career'] = random.randint(1, 17)
    user['bio'] = "Hey!, I'm " + user['name']
    user['go_out'] = random.randint(1, 7)
    user['date'] = random.randint(1, 7)
    user['goal'] = random.randint(1, 6)
    user['imprace'] = random.randint(1, 10)
    user['imprelig'] = random.randint(1, 10)
    
    users.append(user)
    
with open('users.json', 'w') as fp:
    json.dump(users, fp)

# %%
def transform_str_to_num(user):
    transformed_user = {}
    transformed_user['name'] = user['name']
    transformed_user['gender'] = details['strToNum']['gender'][user['gender']]
    transformed_user['age'] = user['age']
    transformed_user['race'] = details['strToNum']['race'][user['race']]
    transformed_user['field'] = details['strToNum']['field'][user['field']]
    transformed_user['career'] = details['strToNum']['career'][user['career']]
    transformed_user['bio'] = user['bio']
    transformed_user['date'] = details['strToNum']['date'][user['date']]
    transformed_user['go_out'] = details['strToNum']['go_out'][user['go_out']]
    transformed_user['goal'] = details['strToNum']['goal'][user['goal']]
    transformed_user['imprace'] = user['imprace']
    transformed_user['imprelig'] = user['imprelig']
    
    return transformed_user

# %%
def transform_num_to_str(user):
    transformed_user = {}
    transformed_user['name'] = user['name']
    transformed_user['gender'] = details['numToStr']['gender'][str(user['gender'])]
    transformed_user['age'] = user['age']
    transformed_user['race'] = details['numToStr']['race'][str(user['race'])]
    transformed_user['field'] = details['numToStr']['field'][str(user['field'])]
    transformed_user['career'] = details['numToStr']['career'][str(user['career'])]
    transformed_user['bio'] = user['bio']
    transformed_user['date'] = details['numToStr']['date'][str(user['date'])]
    transformed_user['go_out'] = details['numToStr']['go_out'][str(user['go_out'])]
    transformed_user['goal'] = details['numToStr']['goal'][str(user['goal'])]
    transformed_user['imprace'] = user['imprace']
    transformed_user['imprelig'] = user['imprelig']
    
    return transformed_user

# %%
def merge_user(user1, user2):
    '''
    Transform data from user and partner by merging necessary info into a row
    '''
    age_o = user2['age']
    race_o = user2['race']
    age = user1['age']
    field_cd = user1['field']
    race = user1['race']
    imprace = user1['imprace']
    goal = user1['goal']
    career_c = user1['career']
    field_cd_o = user2['field']
    imprace_o = user2['imprace']
    goal_o = user2['goal']
    career_c_o = user2['career']
    go_out = user1['go_out']
    date = user1['date']
    imprelig = user1['imprelig']
    imprelig_o = user2['imprelig']
    samerace = int(race == race_o)
    go_out_o = user2['go_out']
    date_o = user2['date']
    
    return [samerace, age_o, race_o, age, field_cd, race, imprace, goal, career_c, field_cd_o, imprace_o, goal_o, career_c_o, go_out, date, imprelig, imprelig_o, go_out_o, date_o]

# %%
def find_partners(user):
    '''
    Take partners based on gender
    If the user is male, take the female users
    If the user is female, take the male users
    '''
    partners = []
    for partner in users:
        if str(user['gender']) == '1':
            if str(partner['gender']) == '2':
                partners.append(partner)
        elif str(user['gender']) == '2':
            if str(partner['gender']) == '1':
                partners.append(partner)   
    return partners

# %%
def recommendations(user, partners):
    '''
    Predict match probability for each partners 
    '''
    partners = np.array(partners)
    # Transform data type for prediction 
    X = []
    for p in partners:
        merge_result = merge_user(user, p)
        X.append(merge_result)
        
    # Predict the target 'match' 
    results = model.predict_proba(X)
    results = results.transpose()
    results = results[1]
    df_results = pd.DataFrame(results)
    df_results.rename(columns={0: "match"})
    transformed_partners = []
    
    # Transform partners before showing to the app
    for p in partners:
        transformed = transform_num_to_str(p)
        transformed_partners.append(transformed)
    df_partners = pd.DataFrame(transformed_partners)
    df_partners = pd.merge(df_partners, df_results, left_index=True, right_index=True)
    
    # Sort partners based on match label 
    sorted_partners = df_partners.sort_values(0, ascending=False)
    return sorted_partners

# %%
def produce_card_old(results):
    with gr.Blocks() as block:
        for p in results:
            with gr.Row() as d:
                gr.Image("person.png")
                text = f'''
    {p['name']}, {p['gender']}, {p['age']} years old
    {p['field']}
    {p['career']}
    {p['bio']}
                '''
                gr.Text(text)
    
    return block

# %%
def produce_card(results):
    text_primary = ""
    for p in results:
        print(p)
        text = '''
{}, {}, {} years old
Field: {}
Career: {}
Bio: {}
        '''.format(p['name'], p['gender'], p['age'], p['field'], p['career'], p['bio'])
        text_primary = text_primary + text    
    return text_primary

# %%
def inputProfile(Name, Gender, Age, Race, Field, Career, Bio, GoOut, Date, Goal, ImpRelig, ImpRace):
    new_user = dict()
    new_user['name'] = Name
    new_user['gender'] = Gender
    new_user['age'] = Age
    new_user['race'] = Race
    new_user['field'] = Field
    new_user['career'] = Career
    new_user['bio'] = Bio
    new_user['go_out'] = GoOut
    new_user['date'] = Date
    new_user['goal'] = Goal
    new_user['imprace'] = ImpRelig
    new_user['imprelig'] = ImpRace
    
    transformed_user = transform_str_to_num(new_user)
    partners = find_partners(transformed_user)
    results = recommendations(transformed_user, partners)
    
    dict_results = results.to_dict('records')
    
    fix_results = produce_card(dict_results)

    return fix_results

# %%
# Interface
demo = gr.Interface(
    inputProfile,
    title="Companero",
    description="Input your Profile, Behavior, and Preferences here!",
    inputs = [
        gr.Textbox(lines=1, placeholder="Your name here..."),
        gr.Radio(["Male", "Female"]),
        gr.Slider(20, 35),
        gr.Radio(["Black/African American",
                "European/Caucasian-American",
                "Latino/Hispanic American",
                "Asian/Pacific Islander/Asian-American",
                "Native American",
                "Other"]),
        gr.Radio(["Law",
                "Math",
                "Social Science, Psychologist",
                "Medical Science, Pharmaceuticals, and Bio Tech", 
                "Engineering",  
                "English/Creative Writing/ Journalism", 
                "History/Religion/Philosophy", 
                "Business/Econ/Finance", 
                "Education, Academia", 
                "Biological Sciences/Chemistry/Physics",
                "Social Work", 
                "Undergrad/undecided",
                "Political Science/International Affairs", 
                "Film",
                "Fine Arts/Arts Administration",
                "Languages",
                "Architecture",
                "Other"]),
        gr.Radio(["Lawyer",
                "Academic/Research",
                "Psychologist ",
                "Doctor/Medicine",
                "Engineer",
                "Creative Arts/Entertainment",
                "Banking/Consulting/Finance/Marketing/Business/CEO/Entrepreneur/Admin",
                "Real Estate",
                "International/Humanitarian Affairs",
                "Undecided",
                "Social Work",
                "Speech Pathology",
                "Politics",
                "Pro sports/Athletics",
                "Other",
                "Journalism",
                "Architecture"]),
        gr.Textbox(lines=5, placeholder="Your bio description here..."),
        gr.Radio(["Several times a week",
                  "Twice a week",
                  "Once a week",
                  "Twice a month",
                  "Once a month",
                  "Several times a year",
                  "Almost never",]),
        gr.Radio(["Several times a week",
                  "Twice a week",
                  "Once a week",
                  "Twice a month",
                  "Once a month",
                  "Several times a year",
                  "Almost never",]),
        gr.Radio(["Seemed like a fun night out",
                "To meet new people",
                "To get a date",
                "Looking for a serious relationship",
                "To say I did it",
                "Other"]),
        gr.Slider(0, 10),
        gr.Slider(0, 10)
    ],
    outputs = "text"    
)

demo.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7867
# Running on public URL: https://c95d4e91fb24f99b.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://c95d4e91fb24f99b.gradio.app" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# C:\Users\TEMP\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# {'name': 'Jessie Cashman', 'gender': 'Male', 'age': 29, 'race': 'Latino/Hispanic American', 'field': 'Social Science, Psychologist', 'career': 'Creative Arts/Entertainment', 'bio': "Hey!, I'm Jessie Cashman", 'date': 'Almost never', 'go_out': 'Almost never', 'goal': 'Looking for a serious relationship', 'imprace': 9, 'imprelig': 1, 0: 0.2664285714285714}
# {'name': 'Carmen Livingston', 'gender': 'Male', 'age': 28, 'race': 'Latino/Hispanic American', 'field': 'English/Creative Writing/ Journalism', 'career': 'Creative Arts/Entertainment', 'bio': "Hey!, I'm Carmen Livingston", 'date': 'Twice a month', 'go_out': 'Several times a year', 'goal': 'To say I did it', 'imprace': 5, 'imprelig': 3, 0: 0.25285714285714284}
# {'name': 'Adam Johnson', 'gender': 'Male', 'age': 23, 'race': 'Asian/Pacific Islander/Asian-American', 'field': 'Social Science, Psychologist', 'career': 'Creative Arts/Entertainment', 'bio': "Hey!, I'm Adam Johnson", 'date': 'Twice a week', 'go_out': 'Twice a month', 'goal': 'Other', 'imprace': 3, 'imprelig': 10, 0: 0.2357142857142857}
# {'name': 'Paul Bond', 'gender': 'Male', 'age': 30, 'race': 'Black/African American', 'field': 'Languages', 'career': 'Creative Arts/Entertainment', 'bio': "Hey!, I'm Paul Bond", 'date': 'Several times a year', 'go_out': 'Several times a week', 'goal': 'Other', 'imprace': 1, 'imprelig': 1, 0: 0.21}
# {'name': 'Justin Boulware', 'gender': 'Male', 'age': 25, 'race': 'Black/African American', 'field': 'History/Religion/Philosophy', 'career': 'Academic/Research', 'bio': "Hey!, I'm Justin Boulware", 'date': 'Several times a week', 'go_out': 'Once a month', 'goal': 'Looking for a serious relationship', 'imprace': 2, 'imprelig': 6, 0: 0.205}
# {'name': 'Frederick Fontenot', 'gender': 'Male', 'age': 33, 'race': 'European/Caucasian-American', 'field': 'Social Science, Psychologist', 'career': 'Creative Arts/Entertainment', 'bio': "Hey!, I'm Frederick Fontenot", 'date': 'Several times a year', 'go_out': 'Several times a year', 'goal': 'Seemed like a fun night out', 'imprace': 8, 'imprelig': 6, 0: 0.20214285714285715}
# {'name': 'Kirby Weeden', 'gender': 'Male', 'age': 21, 'race': 'Black/African American', 'field': 'Engineering', 'career': 'Engineer', 'bio': "Hey!, I'm Kirby Weeden", 'date': 'Almost never', 'go_out': 'Once a week', 'goal': 'Seemed like a fun night out', 'imprace': 4, 'imprelig': 10, 0: 0.19857142857142857}
# {'name': 'Richard Hayes', 'gender': 'Male', 'age': 24, 'race': 'Black/African American', 'field': 'Political Science/International Affairs', 'career': 'Real Estate', 'bio': "Hey!, I'm Richard Hayes", 'date': 'Twice a month', 'go_out': 'Several times a week', 'goal': 'Looking for a serious relationship', 'imprace': 1, 'imprelig': 9, 0: 0.19785714285714287}
# {'name': 'Charles Stokes', 'gender': 'Male', 'age': 30, 'race': 'European/Caucasian-American', 'field': 'Education, Academia', 'career': 'Engineer', 'bio': "Hey!, I'm Charles Stokes", 'date': 'Once a week', 'go_out': 'Twice a month', 'goal': 'Looking for a serious relationship', 'imprace': 6, 'imprelig': 8, 0: 0.19642857142857142}
# {'name': 'George Kamp', 'gender': 'Male', 'age': 21, 'race': 'Black/African American', 'field': 'Architecture', 'career': 'Speech Pathology', 'bio': "Hey!, I'm George Kamp", 'date': 'Once a week', 'go_out': 'Several times a week', 'goal': 'Looking for a serious relationship', 'imprace': 4, 'imprelig': 8, 0: 0.195}
# {'name': 'Robert Koch', 'gender': 'Male', 'age': 29, 'race': 'Black/African American', 'field': 'English/Creative Writing/ Journalism', 'career': 'International/Humanitarian Affairs', 'bio': "Hey!, I'm Robert Koch", 'date': 'Once a month', 'go_out': 'Twice a month', 'goal': 'To meet new people', 'imprace': 2, 'imprelig': 8, 0: 0.18857142857142858}
# {'name': 'Irving Jackson', 'gender': 'Male', 'age': 29, 'race': 'Native American', 'field': 'History/Religion/Philosophy', 'career': 'Psychologist ', 'bio': "Hey!, I'm Irving Jackson", 'date': 'Several times a week', 'go_out': 'Twice a month', 'goal': 'Seemed like a fun night out', 'imprace': 6, 'imprelig': 10, 0: 0.18571428571428572}
# {'name': 'Robert Vil', 'gender': 'Male', 'age': 20, 'race': 'European/Caucasian-American', 'field': 'Biological Sciences/Chemistry/Physics', 'career': 'Lawyer', 'bio': "Hey!, I'm Robert Vil", 'date': 'Several times a year', 'go_out': 'Several times a year', 'goal': 'Looking for a serious relationship', 'imprace': 1, 'imprelig': 9, 0: 0.18071428571428572}
# {'name': 'Robert Trinkle', 'gender': 'Male', 'age': 20, 'race': 'Native American', 'field': 'Languages', 'career': 'Doctor/Medicine', 'bio': "Hey!, I'm Robert Trinkle", 'date': 'Twice a month', 'go_out': 'Almost never', 'goal': 'Looking for a serious relationship', 'imprace': 10, 'imprelig': 5, 0: 0.17857142857142858}
# {'name': 'Richard Santos', 'gender': 'Male', 'age': 21, 'race': 'Other', 'field': 'Education, Academia', 'career': 'Academic/Research', 'bio': "Hey!, I'm Richard Santos", 'date': 'Once a month', 'go_out': 'Several times a year', 'goal': 'Looking for a serious relationship', 'imprace': 1, 'imprelig': 6, 0: 0.17857142857142858}
# {'name': 'Timothy Walker', 'gender': 'Male', 'age': 35, 'race': 'Latino/Hispanic American', 'field': 'Other', 'career': 'Banking/Consulting/Finance/Marketing/Business/CEO/Entrepreneur/Admin', 'bio': "Hey!, I'm Timothy Walker", 'date': 'Once a month', 'go_out': 'Once a week', 'goal': 'Other', 'imprace': 8, 'imprelig': 7, 0: 0.17642857142857143}
# {'name': 'Andres Pierce', 'gender': 'Male', 'age': 28, 'race': 'European/Caucasian-American', 'field': 'Business/Econ/Finance', 'career': 'Real Estate', 'bio': "Hey!, I'm Andres Pierce", 'date': 'Once a week', 'go_out': 'Almost never', 'goal': 'To meet new people', 'imprace': 2, 'imprelig': 9, 0: 0.1707142857142857}
# {'name': 'Christopher Oxford', 'gender': 'Male', 'age': 25, 'race': 'Native American', 'field': 'Other', 'career': 'International/Humanitarian Affairs', 'bio': "Hey!, I'm Christopher Oxford", 'date': 'Several times a week', 'go_out': 'Almost never', 'goal': 'Looking for a serious relationship', 'imprace': 8, 'imprelig': 5, 0: 0.17}
# {'name': 'William Gaskamp', 'gender': 'Male', 'age': 32, 'race': 'Asian/Pacific Islander/Asian-American', 'field': 'Architecture', 'career': 'Architecture', 'bio': "Hey!, I'm William Gaskamp", 'date': 'Several times a year', 'go_out': 'Almost never', 'goal': 'Other', 'imprace': 5, 'imprelig': 9, 0: 0.16642857142857143}
# {'name': 'Alfred Mcluen', 'gender': 'Male', 'age': 22, 'race': 'Black/African American', 'field': 'Business/Econ/Finance', 'career': 'Other', 'bio': "Hey!, I'm Alfred Mcluen", 'date': 'Almost never', 'go_out': 'Several times a year', 'goal': 'To say I did it', 'imprace': 5, 'imprelig': 10, 0: 0.13357142857142856}
# C:\Users\TEMP\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# {'name': 'Laura Lyell', 'gender': 'Female', 'age': 20, 'race': 'Asian/Pacific Islander/Asian-American', 'field': 'Social Science, Psychologist', 'career': 'Academic/Research', 'bio': "Hey!, I'm Laura Lyell", 'date': 'Once a week', 'go_out': 'Twice a week', 'goal': 'To say I did it', 'imprace': 4, 'imprelig': 2, 0: 0.3221428571428571}
# {'name': 'Cheryl Hewitt', 'gender': 'Female', 'age': 29, 'race': 'Asian/Pacific Islander/Asian-American', 'field': 'Medical Science, Pharmaceuticals, and Bio Tech', 'career': 'Undecided', 'bio': "Hey!, I'm Cheryl Hewitt", 'date': 'Almost never', 'go_out': 'Several times a year', 'goal': 'To meet new people', 'imprace': 10, 'imprelig': 9, 0: 0.25642857142857145}
# {'name': 'Rosemary Scott', 'gender': 'Female', 'age': 20, 'race': 'European/Caucasian-American', 'field': 'English/Creative Writing/ Journalism', 'career': 'Journalism', 'bio': "Hey!, I'm Rosemary Scott", 'date': 'Once a week', 'go_out': 'Twice a month', 'goal': 'Seemed like a fun night out', 'imprace': 4, 'imprelig': 7, 0: 0.21214285714285713}
# {'name': 'Ashley Mackay', 'gender': 'Female', 'age': 36, 'race': 'Native American', 'field': 'Education, Academia', 'career': 'Lawyer', 'bio': "Hey!, I'm Ashley Mackay", 'date': 'Several times a year', 'go_out': 'Once a month', 'goal': 'To get a date', 'imprace': 7, 'imprelig': 10, 0: 0.2007142857142857}
# {'name': 'Linda Whitfield', 'gender': 'Female', 'age': 33, 'race': 'Black/African American', 'field': 'Social Science, Psychologist', 'career': 'Creative Arts/Entertainment', 'bio': "Hey!, I'm Linda Whitfield", 'date': 'Once a week', 'go_out': 'Twice a week', 'goal': 'Seemed like a fun night out', 'imprace': 3, 'imprelig': 9, 0: 0.19785714285714287}
# {'name': 'Virgie Koon', 'gender': 'Female', 'age': 35, 'race': 'Black/African American', 'field': 'Engineering', 'career': 'Speech Pathology', 'bio': "Hey!, I'm Virgie Koon", 'date': 'Once a month', 'go_out': 'Once a month', 'goal': 'Seemed like a fun night out', 'imprace': 4, 'imprelig': 3, 0: 0.19071428571428573}
# {'name': 'Wendy Thomas', 'gender': 'Female', 'age': 26, 'race': 'Asian/Pacific Islander/Asian-American', 'field': 'Other', 'career': 'Real Estate', 'bio': "Hey!, I'm Wendy Thomas", 'date': 'Several times a year', 'go_out': 'Twice a week', 'goal': 'To say I did it', 'imprace': 9, 'imprelig': 5, 0: 0.19071428571428573}
# {'name': 'Elizabeth Joyner', 'gender': 'Female', 'age': 20, 'race': 'Other', 'field': 'Other', 'career': 'Journalism', 'bio': "Hey!, I'm Elizabeth Joyner", 'date': 'Once a week', 'go_out': 'Several times a year', 'goal': 'To get a date', 'imprace': 10, 'imprelig': 5, 0: 0.18642857142857142}
# {'name': 'Marianne Vanhamlin', 'gender': 'Female', 'age': 35, 'race': 'Latino/Hispanic American', 'field': 'Law', 'career': 'Undecided', 'bio': "Hey!, I'm Marianne Vanhamlin", 'date': 'Once a month', 'go_out': 'Several times a week', 'goal': 'Seemed like a fun night out', 'imprace': 9, 'imprelig': 1, 0: 0.18642857142857142}
# {'name': 'Julia Barnhart', 'gender': 'Female', 'age': 26, 'race': 'European/Caucasian-American', 'field': 'Business/Econ/Finance', 'career': 'Politics', 'bio': "Hey!, I'm Julia Barnhart", 'date': 'Twice a week', 'go_out': 'Twice a month', 'goal': 'To say I did it', 'imprace': 9, 'imprelig': 8, 0: 0.18571428571428572}
# {'name': 'Nicole Watters', 'gender': 'Female', 'age': 34, 'race': 'Asian/Pacific Islander/Asian-American', 'field': 'Biological Sciences/Chemistry/Physics', 'career': 'Lawyer', 'bio': "Hey!, I'm Nicole Watters", 'date': 'Once a week', 'go_out': 'Almost never', 'goal': 'To get a date', 'imprace': 10, 'imprelig': 6, 0: 0.185}
# {'name': 'Margaret Parra', 'gender': 'Female', 'age': 27, 'race': 'Black/African American', 'field': 'Social Science, Psychologist', 'career': 'Creative Arts/Entertainment', 'bio': "Hey!, I'm Margaret Parra", 'date': 'Several times a year', 'go_out': 'Twice a month', 'goal': 'To get a date', 'imprace': 2, 'imprelig': 10, 0: 0.18357142857142858}
# {'name': 'Audra Vidot', 'gender': 'Female', 'age': 33, 'race': 'Latino/Hispanic American', 'field': 'Undergrad/undecided', 'career': 'Journalism', 'bio': "Hey!, I'm Audra Vidot", 'date': 'Twice a month', 'go_out': 'Once a week', 'goal': 'Looking for a serious relationship', 'imprace': 6, 'imprelig': 10, 0: 0.1742857142857143}
# {'name': 'Andrea Davidson', 'gender': 'Female', 'age': 33, 'race': 'Black/African American', 'field': 'Biological Sciences/Chemistry/Physics', 'career': 'Social Work', 'bio': "Hey!, I'm Andrea Davidson", 'date': 'Once a month', 'go_out': 'Once a week', 'goal': 'Looking for a serious relationship', 'imprace': 10, 'imprelig': 7, 0: 0.17285714285714285}
# {'name': 'Aimee Olson', 'gender': 'Female', 'age': 30, 'race': 'Asian/Pacific Islander/Asian-American', 'field': 'Biological Sciences/Chemistry/Physics', 'career': 'Politics', 'bio': "Hey!, I'm Aimee Olson", 'date': 'Several times a week', 'go_out': 'Twice a month', 'goal': 'Looking for a serious relationship', 'imprace': 3, 'imprelig': 1, 0: 0.17}
# {'name': 'Sherrie Fonville', 'gender': 'Female', 'age': 32, 'race': 'Black/African American', 'field': 'Education, Academia', 'career': 'Politics', 'bio': "Hey!, I'm Sherrie Fonville", 'date': 'Twice a week', 'go_out': 'Several times a year', 'goal': 'To meet new people', 'imprace': 9, 'imprelig': 8, 0: 0.16642857142857143}
# {'name': 'Rebecca Benton', 'gender': 'Female', 'age': 36, 'race': 'Native American', 'field': 'Law', 'career': 'Engineer', 'bio': "Hey!, I'm Rebecca Benton", 'date': 'Almost never', 'go_out': 'Several times a week', 'goal': 'To say I did it', 'imprace': 3, 'imprelig': 8, 0: 0.16285714285714287}
# {'name': 'Molly Connor', 'gender': 'Female', 'age': 36, 'race': 'Native American', 'field': 'Other', 'career': 'Pro sports/Athletics', 'bio': "Hey!, I'm Molly Connor", 'date': 'Several times a year', 'go_out': 'Once a month', 'goal': 'Seemed like a fun night out', 'imprace': 1, 'imprelig': 3, 0: 0.14357142857142857}
# {'name': 'Lori Jensen', 'gender': 'Female', 'age': 29, 'race': 'Native American', 'field': 'Social Work', 'career': 'Speech Pathology', 'bio': "Hey!, I'm Lori Jensen", 'date': 'Once a month', 'go_out': 'Several times a week', 'goal': 'To get a date', 'imprace': 4, 'imprelig': 1, 0: 0.14}
# {'name': 'Jo Newell', 'gender': 'Female', 'age': 35, 'race': 'Black/African American', 'field': 'Film', 'career': 'Journalism', 'bio': "Hey!, I'm Jo Newell", 'date': 'Several times a year', 'go_out': 'Several times a week', 'goal': 'Looking for a serious relationship', 'imprace': 9, 'imprelig': 7, 0: 0.13714285714285715}
# C:\Users\TEMP\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# {'name': 'Laura Lyell', 'gender': 'Female', 'age': 20, 'race': 'Asian/Pacific Islander/Asian-American', 'field': 'Social Science, Psychologist', 'career': 'Academic/Research', 'bio': "Hey!, I'm Laura Lyell", 'date': 'Once a week', 'go_out': 'Twice a week', 'goal': 'To say I did it', 'imprace': 4, 'imprelig': 2, 0: 0.3464285714285714}
# {'name': 'Cheryl Hewitt', 'gender': 'Female', 'age': 29, 'race': 'Asian/Pacific Islander/Asian-American', 'field': 'Medical Science, Pharmaceuticals, and Bio Tech', 'career': 'Undecided', 'bio': "Hey!, I'm Cheryl Hewitt", 'date': 'Almost never', 'go_out': 'Several times a year', 'goal': 'To meet new people', 'imprace': 10, 'imprelig': 9, 0: 0.2592857142857143}
# {'name': 'Rosemary Scott', 'gender': 'Female', 'age': 20, 'race': 'European/Caucasian-American', 'field': 'English/Creative Writing/ Journalism', 'career': 'Journalism', 'bio': "Hey!, I'm Rosemary Scott", 'date': 'Once a week', 'go_out': 'Twice a month', 'goal': 'Seemed like a fun night out', 'imprace': 4, 'imprelig': 7, 0: 0.20785714285714285}
# {'name': 'Wendy Thomas', 'gender': 'Female', 'age': 26, 'race': 'Asian/Pacific Islander/Asian-American', 'field': 'Other', 'career': 'Real Estate', 'bio': "Hey!, I'm Wendy Thomas", 'date': 'Several times a year', 'go_out': 'Twice a week', 'goal': 'To say I did it', 'imprace': 9, 'imprelig': 5, 0: 0.17642857142857143}
# {'name': 'Linda Whitfield', 'gender': 'Female', 'age': 33, 'race': 'Black/African American', 'field': 'Social Science, Psychologist', 'career': 'Creative Arts/Entertainment', 'bio': "Hey!, I'm Linda Whitfield", 'date': 'Once a week', 'go_out': 'Twice a week', 'goal': 'Seemed like a fun night out', 'imprace': 3, 'imprelig': 9, 0: 0.1757142857142857}
# {'name': 'Nicole Watters', 'gender': 'Female', 'age': 34, 'race': 'Asian/Pacific Islander/Asian-American', 'field': 'Biological Sciences/Chemistry/Physics', 'career': 'Lawyer', 'bio': "Hey!, I'm Nicole Watters", 'date': 'Once a week', 'go_out': 'Almost never', 'goal': 'To get a date', 'imprace': 10, 'imprelig': 6, 0: 0.17357142857142857}
# {'name': 'Marianne Vanhamlin', 'gender': 'Female', 'age': 35, 'race': 'Latino/Hispanic American', 'field': 'Law', 'career': 'Undecided', 'bio': "Hey!, I'm Marianne Vanhamlin", 'date': 'Once a month', 'go_out': 'Several times a week', 'goal': 'Seemed like a fun night out', 'imprace': 9, 'imprelig': 1, 0: 0.17142857142857143}
# {'name': 'Ashley Mackay', 'gender': 'Female', 'age': 36, 'race': 'Native American', 'field': 'Education, Academia', 'career': 'Lawyer', 'bio': "Hey!, I'm Ashley Mackay", 'date': 'Several times a year', 'go_out': 'Once a month', 'goal': 'To get a date', 'imprace': 7, 'imprelig': 10, 0: 0.16642857142857143}
# {'name': 'Margaret Parra', 'gender': 'Female', 'age': 27, 'race': 'Black/African American', 'field': 'Social Science, Psychologist', 'career': 'Creative Arts/Entertainment', 'bio': "Hey!, I'm Margaret Parra", 'date': 'Several times a year', 'go_out': 'Twice a month', 'goal': 'To get a date', 'imprace': 2, 'imprelig': 10, 0: 0.165}
# {'name': 'Aimee Olson', 'gender': 'Female', 'age': 30, 'race': 'Asian/Pacific Islander/Asian-American', 'field': 'Biological Sciences/Chemistry/Physics', 'career': 'Politics', 'bio': "Hey!, I'm Aimee Olson", 'date': 'Several times a week', 'go_out': 'Twice a month', 'goal': 'Looking for a serious relationship', 'imprace': 3, 'imprelig': 1, 0: 0.16285714285714287}
# {'name': 'Virgie Koon', 'gender': 'Female', 'age': 35, 'race': 'Black/African American', 'field': 'Engineering', 'career': 'Speech Pathology', 'bio': "Hey!, I'm Virgie Koon", 'date': 'Once a month', 'go_out': 'Once a month', 'goal': 'Seemed like a fun night out', 'imprace': 4, 'imprelig': 3, 0: 0.16214285714285714}
# {'name': 'Elizabeth Joyner', 'gender': 'Female', 'age': 20, 'race': 'Other', 'field': 'Other', 'career': 'Journalism', 'bio': "Hey!, I'm Elizabeth Joyner", 'date': 'Once a week', 'go_out': 'Several times a year', 'goal': 'To get a date', 'imprace': 10, 'imprelig': 5, 0: 0.15857142857142856}
# {'name': 'Julia Barnhart', 'gender': 'Female', 'age': 26, 'race': 'European/Caucasian-American', 'field': 'Business/Econ/Finance', 'career': 'Politics', 'bio': "Hey!, I'm Julia Barnhart", 'date': 'Twice a week', 'go_out': 'Twice a month', 'goal': 'To say I did it', 'imprace': 9, 'imprelig': 8, 0: 0.15785714285714286}
# {'name': 'Lori Jensen', 'gender': 'Female', 'age': 29, 'race': 'Native American', 'field': 'Social Work', 'career': 'Speech Pathology', 'bio': "Hey!, I'm Lori Jensen", 'date': 'Once a month', 'go_out': 'Several times a week', 'goal': 'To get a date', 'imprace': 4, 'imprelig': 1, 0: 0.15428571428571428}
# {'name': 'Andrea Davidson', 'gender': 'Female', 'age': 33, 'race': 'Black/African American', 'field': 'Biological Sciences/Chemistry/Physics', 'career': 'Social Work', 'bio': "Hey!, I'm Andrea Davidson", 'date': 'Once a month', 'go_out': 'Once a week', 'goal': 'Looking for a serious relationship', 'imprace': 10, 'imprelig': 7, 0: 0.15428571428571428}
# {'name': 'Sherrie Fonville', 'gender': 'Female', 'age': 32, 'race': 'Black/African American', 'field': 'Education, Academia', 'career': 'Politics', 'bio': "Hey!, I'm Sherrie Fonville", 'date': 'Twice a week', 'go_out': 'Several times a year', 'goal': 'To meet new people', 'imprace': 9, 'imprelig': 8, 0: 0.15142857142857144}
# {'name': 'Rebecca Benton', 'gender': 'Female', 'age': 36, 'race': 'Native American', 'field': 'Law', 'career': 'Engineer', 'bio': "Hey!, I'm Rebecca Benton", 'date': 'Almost never', 'go_out': 'Several times a week', 'goal': 'To say I did it', 'imprace': 3, 'imprelig': 8, 0: 0.14142857142857143}
# {'name': 'Jo Newell', 'gender': 'Female', 'age': 35, 'race': 'Black/African American', 'field': 'Film', 'career': 'Journalism', 'bio': "Hey!, I'm Jo Newell", 'date': 'Several times a year', 'go_out': 'Several times a week', 'goal': 'Looking for a serious relationship', 'imprace': 9, 'imprelig': 7, 0: 0.12071428571428572}
# {'name': 'Audra Vidot', 'gender': 'Female', 'age': 33, 'race': 'Latino/Hispanic American', 'field': 'Undergrad/undecided', 'career': 'Journalism', 'bio': "Hey!, I'm Audra Vidot", 'date': 'Twice a month', 'go_out': 'Once a week', 'goal': 'Looking for a serious relationship', 'imprace': 6, 'imprelig': 10, 0: 0.11928571428571429}
# {'name': 'Molly Connor', 'gender': 'Female', 'age': 36, 'race': 'Native American', 'field': 'Other', 'career': 'Pro sports/Athletics', 'bio': "Hey!, I'm Molly Connor", 'date': 'Several times a year', 'go_out': 'Once a month', 'goal': 'Seemed like a fun night out', 'imprace': 1, 'imprelig': 3, 0: 0.10642857142857143}
